# %% [markdown]
# # Bernoulli and Binomial Distribution - Lab
#
# ## Introduction
# In this lab, you'll practice your newly gained knowledge on the Bernoulli and Binomial Distribution.
#
# ## Objectives
# You will be able to:
#
# * Apply the formulas for the Binomial and Bernoulli distribution to calculate the probability of a specific event
# * Use `numpy` to randomly generate Binomial and Bernoulli trials
# * Use `matplotlib` to show the output of generated Binomial and Bernoulli trials
#
# ## Apply the formulas for the Binomial and Bernoulli distributions
#
# When playing a game of bowling, what is the probability of throwing exactly 3 strikes in a game with 10 rounds? Assume that the probability of throwing a strike is 25% for each round. Use the formula for the Binomial distribution to get to the answer. You've created this before, so we provide you with the function for factorials again:

# %%
def factorial(n):
    prod = 1
    while n >= 1:
        prod = prod * n
        n = n - 1
    return prod

# %%
p_3_strikes = (factorial(10)/(factorial(3)*factorial(10-3))) * (.25)**3 * (1-.25)**(10-3)
p_3_strikes
#answer = 0.2502822
# Out:
# 0.25028228759765625

# %% [markdown]
# Now, create a function for the Binomial distribution with three arguments $n$, $p$ and $k$ just like in the formula:
#
# $$ \large P(Y=k)= \binom{n}{k} p^k(1-p)^{(n-k)}$$

# %%
def binom_distr(n,p,k):
    return (factorial(n)/(factorial(k)*factorial(n-k))) * p**k * (1-p)**(n-k)

# %% [markdown]
# Validate your previous result by applying your new function.

# %%
# Your code here
binom_distr(10, .25, 3)
# Out:
# 0.25028228759765625

# %% [markdown]
# Now write a `for` loop along with your function to compute the probability that you have five strikes or more in one game. You'll want to use `numpy` here!

# %%
import numpy as np
# Your code here
prob = 0
for strikes in np.arange(5,11):
    prob += binom_distr(10, .25, strikes)
print(prob)
# Out:
# 0.07812690734863281

# %% [markdown]
# ## Use a simulation to get the probabilities for all the potential outcomes
#
# Repeat the experiment 5000 times.

# %%
# leave the random seed here for reproducibility of results
np.random.seed(123)

game = 10
prob = 0.25
reps = 5000

results = np.array([np.random.binomial(game, prob) for x in range(reps)])

values, counts = np.unique(results, return_counts=True)

print(values, counts)
# Out:
# [0 1 2 3 4 5 6 7 8] [ 310  941 1368 1286  707  297   78   11    2]

# %%
# the results should look like this:
# [0 1 2 3 4 5 6 7 8]
# [ 310  941 1368 1286  707  297   78   11    2]

# %% [markdown]
# ## Visualize these results
#
# Create the PMF using these empirical results (that is, the proportions based on the values we obtained running the experiment 5000 times).

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

plt.style.use('fivethirtyeight')
plt.figure(figsize=(8,6))
sns.barplot(x=values, y=counts/reps, palette='rocket')
plt.xticks(values)
plt.ylabel('Probability')
plt.title('Strikes / Game - PMF');

# %%
exp = np.array([binom_distr(10, .25, strikes) for strikes in range(11)])

plt.style.use('fivethirtyeight')
plt.figure(figsize=(8,6))
sns.barplot(x=list(range(11)), y=exp, palette='rocket')
plt.xticks(list(range(11)))
plt.ylabel('Probability')
plt.title('Expected Strikes/Game - PMF');

# %% [markdown]
# You should see that, with a 25% strike hit rate, even when simulating 5000 times, an almost perfect and/or perfect game of 9 and 10 strikes didn't even occur once! If you change the random seed, however, you'll see that perfect games will show up occasionally.
#
# Next, let's create the CDF based on these results. You can use `np.cumsum` to obtain cumulative probabilities.

# %%
cum_sums = np.cumsum(counts/reps)

plt.style.use('fivethirtyeight')
plt.figure(figsize=(8,6))
sns.barplot(x=values, y=cum_sums, palette='mako')
plt.xticks(values)
plt.ylabel('Probability')
plt.title('Strikes / Game - CDF');

# %%
cum_sums = np.cumsum(exp)

plt.style.use('fivethirtyeight')
plt.figure(figsize=(8,6))
sns.barplot(x=list(range(11)), y=cum_sums, palette='mako')
plt.xticks(values)
plt.ylabel('Probability')
plt.title('Expected Strikes / Game - CDF');

# %% [markdown]
# ## Summary
#
# Congratulations! In this lab, you practiced your newly gained knowledge of the Bernoulli and Binomial Distribution.
